# %%
import pandas as pd

df1 = pd.read_csv('/Users/Nicole/Documents/540DataPreparation/TermProject/Crime_Data_2010_2017.csv')
df1.head()
# Out:
#    DR Number Date Reported Date Occurred  Time Occurred  Area ID    Area Name  \
# 0    1208575    03/14/2013    03/11/2013           1800       12  77th Street
# 1  102005556    01/25/2010    01/22/2010           2300       20      Olympic
# 2        418    03/19/2013    03/18/2013           2030       18    Southeast
# 3  101822289    11/11/2010    11/10/2010           1800       18    Southeast
# 4   42104479    01/11/2014    01/04/2014           2300       21      Topanga
#
#    Reporting District  Crime Code                    Crime Code Description  \
# 0                1241         626         INTIMATE PARTNER - SIMPLE ASSAULT
# 1                2071         510                          VEHICLE - STOLEN
# 2                1823         510                          VEHICLE - STOLEN
# 3                1803         510                          VEHICLE - STOLEN
# 4                2133         745  VANDALISM - MISDEAMEANOR ($399 OR UNDER)
#
# ...

# %%
# 1. missing values

df1.isnull()
# Out:
#          DR Number  Date Reported  Date Occurred  Time Occurred  Area ID  \
# 0            False          False          False          False    False
# 1            False          False          False          False    False
# 2            False          False          False          False    False
# 3            False          False          False          False    False
# 4            False          False          False          False    False
# ...            ...            ...            ...            ...      ...
# 1584311      False          False          False          False    False
# 1584312      False          False          False          False    False
# 1584313      False          False          False          False    False
# 1584314      False          False          False          False    False
# 1584315      False          False          False          False    False
#
#          Area Name  Reporting District  Crime Code  Crime Code Description  \
# ...

# %%
for c in df1.columns:
    miss = df1[c].isnull().sum()
    if miss>0:
        print("{} has {} missing value(s)".format(c,miss))
    else:
        print("{} has no missing values".format(c))
# Out:
# DR Number has no missing values
# Date Reported has no missing values
# Date Occurred has no missing values
# Time Occurred has no missing values
# Area ID has no missing values
# Area Name has no missing values
# Reporting District has no missing values
# Crime Code has no missing values
# Crime Code Description has 412 missing value(s)
# MO Codes has 171759 missing value(s)
# Victim Age has 128659 missing value(s)
# Victim Sex has 145199 missing value(s)
# Victim Descent has 145232 missing value(s)
# Premise Code has 76 missing value(s)
# Premise Description has 2751 missing value(s)
# Weapon Used Code has 1059559 missing value(s)
# Weapon Description has 1059560 missing value(s)
# Status Code has 2 missing value(s)
# Status Description has no missing values
# Crime Code 1 has 7 missing value(s)
# Crime Code 2 has 1484319 missing value(s)
# Crime Code 3 has 1582133 missing value(s)
# Crime Code 4 has 1584247 missing value(s)
# Address has no missing values
# ...

# %%
df1.fillna('FILL')
# Out:
#          DR Number Date Reported Date Occurred  Time Occurred  Area ID  \
# 0          1208575    03/14/2013    03/11/2013           1800       12
# 1        102005556    01/25/2010    01/22/2010           2300       20
# 2              418    03/19/2013    03/18/2013           2030       18
# 3        101822289    11/11/2010    11/10/2010           1800       18
# 4         42104479    01/11/2014    01/04/2014           2300       21
# ...            ...           ...           ...            ...      ...
# 1584311  172116482    09/07/2017    09/07/2017           1005       21
# 1584312  172116489    09/07/2017    09/07/2017           1200       21
# 1584313  172116491    08/30/2017    07/15/2017              1       21
# 1584314  172116498    09/08/2017    09/08/2017           1845       21
# 1584315  172116510    09/08/2017    07/12/2017           2230       21
#
#            Area Name  Reporting District  Crime Code  \
# 0        77th Street                1241         626
# ...

# %%
df2 = df1.dropna(axis=0)
df2
# Out:
#          DR Number Date Reported Date Occurred  Time Occurred  Area ID  \
# 15370    130222023    11/12/2013    11/11/2013           2330        2
# 29137    130404327    01/09/2013    01/08/2013           1130        4
# 98680    101200908    09/23/2010    09/23/2010           1350       12
# 98711    101200992    11/04/2010    10/31/2010           2300       12
# 225210   100307604    02/24/2010    02/23/2010           2000        3
# 287568   101015135    08/16/2010    08/16/2010            300       10
# 431206   111306660    02/13/2011    02/13/2011           2130       13
# 742020   131522431    12/02/2013    12/02/2013            500       15
# 971319   142008231    04/02/2014    04/02/2014            700       20
# 1018452  150311517    04/29/2015    04/29/2015           1100        3
# 1164101  151806473    02/23/2015    02/21/2015            700       18
# 1329322  161226995    11/04/2016    11/04/2016            630       12
# ...

# %%
# went from 1584316 to 13 rows, but they are all complete with no missing values

# %%
# 2. outliers

df2.plot.box()

# %%
# no outliers/not reasonable to measure by boxplot because there are categorical variables

# %%
# 3. duplicate values for df2

df2.duplicated()
# Out:
# 15370      False
# 29137      False
# 98680      False
# 98711      False
# 225210     False
# 287568     False
# 431206     False
# 742020     False
# 971319     False
# 1018452    False
# 1164101    False
# 1329322    False
# 1331567    False
# dtype: bool

# %%
# 4. replace headers

df3 = df2.rename({'DR Number': 'Dept Report Number', 'MO Codes': 'Method of Operation Codes'}, axis=1)
df3.head()
# Out:
#         Dept Report Number Date Reported Date Occurred  Time Occurred  \
# 15370            130222023    11/12/2013    11/11/2013           2330
# 29137            130404327    01/09/2013    01/08/2013           1130
# 98680            101200908    09/23/2010    09/23/2010           1350
# 98711            101200992    11/04/2010    10/31/2010           2300
# 225210           100307604    02/24/2010    02/23/2010           2000
#
#         Area ID    Area Name  Reporting District  Crime Code  \
# 15370         2      Rampart                 265         121
# 29137         4   Hollenbeck                 497         210
# 98680        12  77th Street                1209         121
# 98711        12  77th Street                1258         121
# 225210        3    Southwest                 395         121
#
#        Crime Code Description  \
# 15370          RAPE, FORCIBLE
# 29137                 ROBBERY
# 98680          RAPE, FORCIBLE
# 98711          RAPE, FORCIBLE
# ...

# %%
# 5. Casing

df4 = df3.apply(lambda x: x.astype(str).str.upper())
df4
# Out:
#         Dept Report Number Date Reported Date Occurred Time Occurred Area ID  \
# 15370            130222023    11/12/2013    11/11/2013          2330       2
# 29137            130404327    01/09/2013    01/08/2013          1130       4
# 98680            101200908    09/23/2010    09/23/2010          1350      12
# 98711            101200992    11/04/2010    10/31/2010          2300      12
# 225210           100307604    02/24/2010    02/23/2010          2000       3
# 287568           101015135    08/16/2010    08/16/2010           300      10
# 431206           111306660    02/13/2011    02/13/2011          2130      13
# 742020           131522431    12/02/2013    12/02/2013           500      15
# 971319           142008231    04/02/2014    04/02/2014           700      20
# 1018452          150311517    04/29/2015    04/29/2015          1100       3
# 1164101          151806473    02/23/2015    02/21/2015           700      18
# ...

# %%
df4.dtypes
# Out:
# Dept Report Number           object
# Date Reported                object
# Date Occurred                object
# Time Occurred                object
# Area ID                      object
# Area Name                    object
# Reporting District           object
# Crime Code                   object
# Crime Code Description       object
# Method of Operation Codes    object
# Victim Age                   object
# Victim Sex                   object
# Victim Descent               object
# Premise Code                 object
# Premise Description          object
# Weapon Used Code             object
# Weapon Description           object
# Status Code                  object
# Status Description           object
# Crime Code 1                 object
# Crime Code 2                 object
# Crime Code 3                 object
# Crime Code 4                 object
# Address                      object
# Cross Street                 object
# Location                     object
# ...

# %%
df4['Dept Report Number'] = pd.to_numeric(df4['Dept Report Number'])
df4['Area ID'] = pd.to_numeric(df4['Area ID'])
df4['Reporting District'] = pd.to_numeric(df4['Reporting District'])
df4['Crime Code'] = pd.to_numeric(df4['Crime Code'])
df4['Victim Age'] = pd.to_numeric(df4['Victim Age'])
df4['Crime Code 1'] = pd.to_numeric(df4['Crime Code 1'])
df4['Crime Code 2'] = pd.to_numeric(df4['Crime Code 2'])
df4['Crime Code 3'] = pd.to_numeric(df4['Crime Code 3'])
df4['Crime Code 4'] = pd.to_numeric(df4['Crime Code 4'])

# %%
# reverted necessary columns back to numerics

df4.dtypes
# Out:
# Dept Report Number             int64
# Date Reported                 object
# Date Occurred                 object
# Time Occurred                 object
# Area ID                        int64
# Area Name                     object
# Reporting District             int64
# Crime Code                     int64
# Crime Code Description        object
# Method of Operation Codes     object
# Victim Age                   float64
# Victim Sex                    object
# Victim Descent                object
# Premise Code                  object
# Premise Description           object
# Weapon Used Code              object
# Weapon Description            object
# Status Code                   object
# Status Description            object
# Crime Code 1                 float64
# Crime Code 2                 float64
# Crime Code 3                 float64
# Crime Code 4                 float64
# Address                       object
# Cross Street                  object
# ...

# %%
df4.to_csv('Milestone2.csv')
